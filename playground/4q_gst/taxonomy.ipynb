# %%
# %load_ext autoreload
# %autoreload 2

import jax.numpy as jnp
from mGST.reporting.reporting import generate_basis_labels
from mGST.compatibility import std2pp
import matplotlib.pyplot as plt
from pygsti.tools.optools import elementary_errorgens, extract_elementary_errorgen_coefficients, error_generator
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Error generators funciton

# %%
num_qubits = 4
dim = 2**num_qubits

# %%
hamiltonian_generators = elementary_errorgens(dim=dim, typ="H", basis="pp")
len(hamiltonian_generators)
# Out:
# 15

# %%
pauli_stochastic_generators = elementary_errorgens(dim=dim, typ="S", basis="pp")
len(pauli_stochastic_generators)
# Out:
# 15

# %%
dim**2 - 1
# Out:
# 255

# %%
correlation_stochastic_generators = elementary_errorgens(dim=dim, typ="C", basis="pp")
len(correlation_stochastic_generators)
# Out:
# 105

# %%
(dim**2 - 1)*(dim**2 - 2)/2
# Out:
# 32385.0

# %% [markdown]
# # Load operators

# %%
ops_gauge_opt = jnp.load("data/ops_gauge_optimized_mgst_4q_rank_4_all.npz")
ops_target = jnp.load("data/ops_target_mgst_4q_rank_4_all.npz")
ops_gauge_opt.keys(), ops_target.keys()
# Out:
# (KeysView(NpzFile 'data/ops_gauge_optimized_mgst_4q_rank_4_all.npz' with keys: kraus, povm, state),
#  KeysView(NpzFile 'data/ops_target_mgst_4q_rank_4_all.npz' with keys: kraus, povm, state))

# %%
kraus_target_pauli, *_ = std2pp(*ops_target.values())
# Convert to pauli basis
kraus_gauge_opt_pauli, *_ = std2pp(*ops_gauge_opt.values())
# Looking only at the last gate (CZ-CZ)
cz_cz_gauge_pauli = kraus_gauge_opt_pauli[-1]
cz_cz_target_pauli = kraus_target_pauli[-1]
cz_cz_gauge_pauli.shape, cz_cz_target_pauli.shape
# Out:
# ((256, 256), (256, 256))

# %%
error_generator_operator = error_generator(gate=cz_cz_gauge_pauli, target_op=cz_cz_target_pauli, mx_basis="pp")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 error_generator_operator = error_generator(gate=cz_cz_gauge_pauli, target_op=cz_cz_target_pauli, mx_basis="pp")
#
# File ~/.pyenv/versions/qcvv-env/lib/python3.11/site-packages/pygsti/tools/optools.py:1431, in error_generator(gate, target_op, mx_basis, typ, logG_weight)
#    1429     logG = _mt.approximate_matrix_log(gate, logT, target_weight=logG_weight)
#    1430 else:
# -> 1431     logG = _mt.approximate_matrix_log(gate, logT)
#    1433 # Both logG and logT *should* be real, so we just take the difference.
#    1434 if _np.linalg.norm(_np.imag(logG)) < TOL and \
#    1435    _np.linalg.norm(_np.imag(logT)) < TOL:
#
# File ~/.pyenv/versions/qcvv-env/lib/python3.11/site-packages/pygsti/tools/matrixtools.py:716, in approximate_matrix_log(m, target_logm, target_weight, tol)
# ...
