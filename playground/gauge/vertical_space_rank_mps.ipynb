# %% [markdown]
# # Goals:
#
# In the previous notebook `vertical_space_rank.ipynb` we successfully analyzed the number of gauges degrees of freedom coming from the unitary action along the Kraus rank.
#
# Now, the goal is to perform a similar analysis for the unitary action along the "bond dimension", similar to the MPS gauge freedom (hence the name of this notebook).
#
# In the case of the MPS gauge freedom, the condition that the generators must satisfy reads
#
# \begin{equation}
#
# \end{equation}
#
# Started: 28.07.2026

# %% [markdown]
# # MPS degrees of freedom

# %%
rank_8 = 8
n_rank_8 = dim_2q * rank_8

kraus_tensor_init_2q_rank_8 = get_compressed_perturbed_kraus_from_superop(superop=kraus_superop_target, rank=rank_8, seed=42)["kraus_tensor"]
gate_index = 0
x_init_rank_8 = kraus_tensor_init_2q_rank_8[gate_index]
x_isom_init_rank_8 = tensor_to_isometry(x_init_rank_8, n_rank_8, p)

# %%
# Let's start with the d=4, r=8 case.
vert_fund_vects_mps= generate_vertical_fundamental_vectors(x=x_isom_init_rank_8, dim_A=dim_2q, gauge_type="mps")
